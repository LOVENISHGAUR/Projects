# %%
import os
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Defining working directoryabs
os.chdir('/Users/lovenishgaur/Documents/DataAnalyst/Bepec/Data Cleaning/')

# %%
# Import Dataset
data = pd.read_excel('Lending Data.xlsx', sheet_name='1a')

# %%
pd.set_option('display.max_rows', data.shape[0]+1)

# %%
data.head()
# Out:
#   Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                         NaN      NaN   -1        -2         -3
# 1       American Express Co.       NY     1   0.23829   0.999544
# 2    First Citizens Banchares      NC     2  0.187393    0.49083
# 3    Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4               Zions Bancorp      UT     4  0.117973   0.260577
#
#   Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# 0              -4       -5                    -6               -7.0
# 1        16350038  3603226  >$50B                        16318089.0
# 2         3914507   117702  $10B-$50B                      378394.0
# 3         2842793   136801  $10B-$50B                      800526.0
# 4         6231770    52612  >$50B                          526206.0
#
#    Number .1  Unnamed: 10  Amount ($1,000).2  Number .2 CC Amount/TA1
# 0       -8.0          NaN               -9.0      -10.0           -11
# ...

# %%
data.keys()
# Out:
# Index(['Name of Lending Institution', 'HQ State', 'Rank', 'TA Ratio1',
#        'TBL Ratio1', 'Amount ($1,000)', 'Number ', 'Lender Asset Size',
#        'Amount ($1,000).1', 'Number .1', 'Unnamed: 10', 'Amount ($1,000).2',
#        'Number .2', 'CC Amount/TA1'],
#       dtype='object')

# %%
data = data.drop(data.index[0])

# %%
data.describe()
# Out:
#        Amount ($1,000).1     Number .1  Unnamed: 10  Amount ($1,000).2  \
# count       9.300000e+01  9.300000e+01          0.0       9.300000e+01
# mean        1.002631e+06  1.985947e+05          NaN       2.045180e+06
# std         2.831968e+06  6.672701e+05          NaN       3.693460e+06
# min         0.000000e+00  0.000000e+00          NaN       0.000000e+00
# 25%         2.052300e+04  7.220000e+02          NaN       1.936390e+05
# 50%         1.414220e+05  7.870000e+03          NaN       8.838740e+05
# 75%         5.292220e+05  3.306600e+04          NaN       2.300008e+06
# max         1.631809e+07  3.603088e+06          NaN       2.615439e+07
#
#            Number .2
# count      93.000000
# mean     8515.956989
# std     15063.903593
# min         0.000000
# 25%       565.000000
# 50%      3511.000000
# 75%     10822.000000
# max    107411.000000

# %%
#Convert Lending Asset Size = Category like 0, 1, 2 etc based on levels available
data['Lender Asset Size'].unique()
# Out:
# array(['>$50B               ', '$10B-$50B           ',
#        '>$10B               ', nan], dtype=object)

# %%
data.replace(['>$50B               ', '$10B-$50B           ',
       '>$10B               ',], 
                     [0, 1, 2],inplace=True,)

# %%
data
# Out:
#                           Name of Lending Institution HQ State Rank  \
# 1                               American Express Co.       NY     1
# 2                            First Citizens Banchares      NC     2
# 3                            Wintrust Financial Corp.      IL     3
# 4                                       Zions Bancorp      UT     4
# 5                             Synovus Financial Corp.      GA     5
# 6                                         BB&T Corp.       NC     6
# 7                                          FNB Corp.       PA     7
# 8                         Capital One Financial Corp.      VA     8
# 9                             Fulton Financial Corp.       PA     8
# 10                            Regions Financial Corp.      AL    10
# 11                                       U S Bancorp.      MN    11
# 12                      First Niagara Financial Grp.       NY    11
# 13                                   Lauritzen Corp.       NE    13
# ...

# %%
data.drop('Unnamed: 10', inplace=True, axis=1)

# %%
data.isna()
# Out:
#     Name of Lending Institution  HQ State   Rank  TA Ratio1  TBL Ratio1  \
# 1                         False     False  False      False       False
# 2                         False     False  False      False       False
# 3                         False     False  False      False       False
# 4                         False     False  False      False       False
# 5                         False     False  False      False       False
# 6                         False     False  False      False       False
# 7                         False     False  False      False       False
# 8                         False     False  False      False       False
# 9                         False     False  False      False       False
# 10                        False     False  False      False       False
# 11                        False     False  False      False       False
# 12                        False     False  False      False       False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 1 to 96
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  96 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         93 non-null     object
#  3   TA Ratio1                    93 non-null     object
#  4   TBL Ratio1                   93 non-null     object
#  5   Amount ($1,000)              93 non-null     object
#  6   Number                       93 non-null     object
#  7   Lender Asset Size            93 non-null     float64
#  8   Amount ($1,000).1            93 non-null     float64
#  9   Number .1                    93 non-null     float64
#  10  Amount ($1,000).2            93 non-null     float64
#  11  Number .2                    93 non-null     float64
#  12  CC Amount/TA1                93 non-null     object
# ...

# %%
data.count()
# Out:
# Name of Lending Institution    96
# HQ State                       93
# Rank                           93
# TA Ratio1                      93
# TBL Ratio1                     93
# Amount ($1,000)                93
# Number                         93
# Lender Asset Size              93
# Amount ($1,000).1              93
# Number .1                      93
# Amount ($1,000).2              93
# Number .2                      93
# CC Amount/TA1                  93
# dtype: int64

# %%
data = data.set_index('Name of Lending Institution')

# %%
data = data.replace(regex = True, to_replace = '[.-]+', value = np.nan)

# %%
data
# Out:
#                                                    HQ State Rank  TA Ratio1  \
# Name of Lending Institution
# American Express Co.                                    NY     1   0.238290
# First Citizens Banchares                                NC     2   0.187393
# Wintrust Financial Corp.                                IL     3   0.168999
# Zions Bancorp                                           UT     4   0.117973
# Synovus Financial Corp.                                 GA     5   0.162333
# BB&T Corp.                                              NC     6   0.053460
# FNB Corp.                                               PA     7   0.127672
# Capital One Financial Corp.                             VA     8   0.027560
# Fulton Financial Corp.                                  PA     8   0.129126
# Regions Financial Corp.                                 AL    10   0.061039
# U S Bancorp.                                            MN    11   0.042109
# ...

# %%
data['Rank'] = pd.to_numeric(data['Rank'], errors='coerce')

# %%
data['Rank'] = data['Rank'].fillna(0).astype(int)

# %%
data
# Out:
#                                                    HQ State  Rank  TA Ratio1  \
# Name of Lending Institution
# American Express Co.                                    NY      1   0.238290
# First Citizens Banchares                                NC      2   0.187393
# Wintrust Financial Corp.                                IL      3   0.168999
# Zions Bancorp                                           UT      4   0.117973
# Synovus Financial Corp.                                 GA      5   0.162333
# BB&T Corp.                                              NC      6   0.053460
# FNB Corp.                                               PA      7   0.127672
# Capital One Financial Corp.                             VA      8   0.027560
# Fulton Financial Corp.                                  PA      8   0.129126
# Regions Financial Corp.                                 AL     10   0.061039
# U S Bancorp.                                            MN     11   0.042109
# ...

# %%
data = data.fillna(data.mean())

# %%
data
# Out:
#                                                    HQ State  Rank  TA Ratio1  \
# Name of Lending Institution
# American Express Co.                                    NY      1   0.238290
# First Citizens Banchares                                NC      2   0.187393
# Wintrust Financial Corp.                                IL      3   0.168999
# Zions Bancorp                                           UT      4   0.117973
# Synovus Financial Corp.                                 GA      5   0.162333
# BB&T Corp.                                              NC      6   0.053460
# FNB Corp.                                               PA      7   0.127672
# Capital One Financial Corp.                             VA      8   0.027560
# Fulton Financial Corp.                                  PA      8   0.129126
# Regions Financial Corp.                                 AL     10   0.061039
# U S Bancorp.                                            MN     11   0.042109
# ...

# %%
data.to_csv(r'/Users/lovenishgaur/Documents/DataAnalyst/Bepec/Data Cleaning/ Lending_Data.csv', index = True)
